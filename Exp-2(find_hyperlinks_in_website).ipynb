# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
#  bs4: Beautiful Soup(bs4) is a Python library for pulling data out of HTML and XML files.
#  requests: Requests allows you to send HTTP/1.1 requests extremely easily.

# %%
url = 'https://www.dkte.ac.in/'
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text, 'html.parser')

# %%
urls = []
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /
# /video
# /photo-gallery
# https://online.dkte.ac.in/parents/
# javascript:void(0);
# /alumini/dkte-alumni-association
# /alumini/alumni-figures-and-details
# /alumini/alumni-photo-gallery
# /alumini/alumni-photo-gallery-international-meet
# /alumini/alumni-photo-gallery-silver-jubilee-batch
# javascript:void(0);
# /news-and-events/anouncement
# /news-and-events/news
# /news-and-events/events
# /contact-us
# javascript:void(0);
# /exam-section/examination-committee
# /exam-section/about-us
# /exam-section/coe-office-staff
# /exam-section/rules-and-regulations
# /exam-section/circulars
# /exam-section/exam-schedule
# /exam-section/exam-forms
# /exam-section/photocopy-and-revaluation
# /exam-section/results
# /exam-section/exam-calendar
# /exam-section/graduation-ceremony
# /exam-section/faq
# /exam-section/covid-19
# javascript:void(0);
# /national-initiatives/institutional-s-innovation-council-iic
# /national-initiatives/startup-policies
# /idea-lab
# /
# /about-us/about-dkte-society
# /about-us/about-dkte-society
# /about-us/chairman-s-message
# /about-us/director-s-message
# /about-us/vision-mission
# /about-us/quality-policy
# /about-us/governing-body
# /about-us/governing-council
# /about-us/academic-council
# /about-us/board-of-examination
# /about-us/key-facutly
# /about-us/how-to-reach
# /about-us/accreditation
# /about-us/institutional-distinctiveness
# /under-graduate
# /under-graduate/textile-department
# /under-graduate/textile-department/b-tech-textile-technology/b-tech-textile-technology-vision-mission
# /under-graduate/textile-department/b-tech-manmade-textile-technology/b-tech-manmade-textile-technology-vision-mission
# /under-graduate/textile-department/b-tech-textile-plant-engineering/b-tech-textile-plant-engineering-mission-vision
# /under-graduate/textile-department/b-tech-textile-chemistry/vision-mission
# /under-graduate/textile-department/b-tech-fashion-technology/b-tech-fashion-vision-mission
# /under-graduate/textile-department/honors-minor-degree
# /under-graduate/engineering-department
# /under-graduate/engineering-department/b-tech-electronics-engineering/b-tech-electronics-vision-mission
# /under-graduate/engineering-department/b-tech-mechanical-engineering/b-tech-mech-vision-mission
# /under-graduate/engineering-department/b-tech-computer-sc-engineering/b-tech-cse-vision-mission
# /under-graduate/engineering-department/b-tech-electronics-telecommunication-engineering/b-tech-etc-vision-mission
# /under-graduate/engineering-department/b-tech-civil-engineering/b-tech-civil-vision-mission
# /under-graduate/engineering-department/b-tech-electrical-engineering/b-tech-ele-vision-mission
# /under-graduate/engineering-department/b-tech-computer-science-artificial-intelligence
# /under-graduate/engineering-department/b-tech-ai-and-data-science
# /under-graduate/b-voc-programs
# /under-graduate/b-voc-programs/web-design-and-mobile-application-development
# /under-graduate/b-voc-programs/solar-pv-panel-installation-and-maintenance
# /under-graduate/b-voc-programs/fashion-technology-apparel-designing
# /under-graduate/b-voc-programs/mobile-and-telephone-mechanic
# /post-graduate
# /post-graduate/engineering-department
# /post-graduate/engineering-department/m-tech-textile-engineering/overview
# /post-graduate/engineering-department/m-tech-electronics-engineering/vision-mission
# /post-graduate/engineering-department/m-tech-mechanical-engineering-product-design-and-development/m-tech-mechanical-vision-mission-objectives
# /post-graduate/engineering-department/m-tech-computer-science-engineering/pg-com-science-vision-mission
# /post-graduate/engineering-department/m-tech-defence-technology
# /post-graduate/phd-programmes
# /post-graduate/phd-programmes/textile-engineering
# /post-graduate/phd-programmes/electronics-engineering
# /post-graduate/phd-programmes/mechanical-engineering
# /post-graduate/phd-programmes/computer-sci-engineering
# /mba
# /mba/top-mba-colleges-in-maharashtra
# /mba/specializations
# /mba/pg-mba-all-mission-vision
# /mba/pg-mba-all-achievements
# /mba/pg-mba-all-syllabus
# /mba/pg-mba-all-board-of-studies
# /mba/pg-mba-all-faculty-profile
# /mba/pg-mba-all-industrial-institute-interaction
# /mba/pg-mba-all-placement
# /mba/pg-mba-all-result
# /mba/pg-mba-all-manedge
# /international-linkages
# /international-linkages/international-admissions
# /international-linkages/international-semester-exchange-program
# /international-linkages/international-internship
# /international-linkages/international-mou
# /international-linkages/international-activities
# http://www.dktesdiploma.com/
# /admissions
# /admissions/ug-admission/admission-process
# /admissions/ug-admission/admission-process
# /admissions/ug-admission/eligibility
# /admissions/ug-admission/contact-admissions-office
# /admissions/ug-admission/other-useful-links
# /admissions/ug-admission/provisional-admission-form
# /admissions/ug-admission/fee-structure
# /admissions/ug-admission/documents-required
# /admissions/ug-admission/vidya-lakshmi-educational-loan
# /admissions/pg-admission/admission-process
# /admissions/pg-admission/admission-process
# /admissions/pg-admission/eligibility
# /admissions/pg-admission/contact-admissions-office
# /admissions/pg-admission/other-useful-links
# /admissions/pg-admission/pg-admission-poster
# /admissions/international-students
# /admissions/international-students/admission-process
# /admissions/international-students/eligibility
# /admissions/international-students/contact-admissions-office
# /placement
# /placement/good-placement-engineering-colleges-in-maharashtra
# /placement/top-engineering-colleges-in-maharashtra-placement-wise
# /placement/recruiters
# /placement/internship
# /placement/why-should-you-recruit-dkte-students
# /placement/testimonials
# /placement/contact-training-and-placement-officer
# /placement/placement-gallary
# /life-dkte
# /life-dkte/facilities
# /life-dkte/library
# /life-dkte/central-computing-facility
# /life-dkte/hostel
# /life-dkte/student-curricular-activities
# /life-dkte/student-co-curricular-activities
# /life-dkte/student-awards
# /life-dkte/student-support
# /life-dkte/code-of-conduct
# /life-dkte/sports
# /life-dkte/industrial-tour
# /life-dkte/bus-facility
# /life-dkte/guest-house
# /best-practices
# /research
# /research/research-overview
# /research/government-sponsored-projects
# /research/mou-signed
# /research/industry-sponsored-laboratories
# /research/patents
# /general-engg
# /general-engg/overview
# /general-engg/laboratory-humanity
# /general-engg/faculty
# /general-engg/syllabus-humanity
# /general-engg/departmental-activity-humanity
# /general-engg/mentor-activity
# /qip
# /video
# /photo-gallery
# https://online.dkte.ac.in/parents/
# javascript:void(0);
# /alumini/dkte-alumni-association
# /alumini/alumni-figures-and-details
# /alumini/alumni-photo-gallery
# /alumini/alumni-photo-gallery-international-meet
# /alumini/alumni-photo-gallery-silver-jubilee-batch
# javascript:void(0);
# /news-and-events/anouncement
# /news-and-events/news
# /news-and-events/events
# /contact-us
# javascript:void(0);
# /exam-section/examination-committee
# /exam-section/about-us
# /exam-section/coe-office-staff
# /exam-section/rules-and-regulations
# /exam-section/circulars
# /exam-section/exam-schedule
# /exam-section/exam-forms
# /exam-section/photocopy-and-revaluation
# /exam-section/results
# /exam-section/exam-calendar
# /exam-section/graduation-ceremony
# /exam-section/faq
# /exam-section/covid-19
# javascript:void(0);
# /national-initiatives/institutional-s-innovation-council-iic
# /national-initiatives/startup-policies
# /idea-lab
# #ImageMainSliderHome
# #ImageMainSliderHome
# /index.php?option=com_k2&view=item&id=303:virtual-international-conference-on-innovations-in-textiles-products-and-processes-itpp-21-on-2nd-and-3rd-september-2021&Itemid=119
# /index.php?option=com_k2&view=item&id=294:in-academic-year-2020-21-610-students-have-been-placed-in-150-companies-through-campus-placement-cell-till-10th-november-2021&Itemid=119
# /index.php?option=com_k2&view=item&id=219:academic-year-2019-20-586-students-have-been-placed-in-155-companies-through-campus-placement-cell-till-31st-december-2020-25-students-have-been-hired-for-an-internship-listed-on-internshala&Itemid=119
# /post-graduate/engineering-department/m-tech-defence-technology
# /exam-section/results
# /2-uncategorised/328-ariia-ranking-2020
# https://drive.google.com/file/d/111UA-imOStgZCPVKnO_9kqWvIlLZFLOr/view?usp=sharing
# /how-to-pay-fees
# /ugc-nsqf-form
# #
# /under-graduate/textile-department
# /under-graduate/engineering-department
# /post-graduate/engineering-department/m-tech-textile-engineering/overview
# /post-graduate/management-department/master-of-business-administration-mba/pg-mba-all-mission-vision
# /news-and-events/news/item/20-mba-admissions-2021-2022
# /news-and-events/news/item/22-institute-s-ranking-in-different-surveys
# /news-and-events/news/item/21-naac-committee-visit
# /news-and-events/news/item/19-1st-graduation-ceremony-photo-gallery
# https://www.dkte.ac.in/news-and-events/news
# /news-and-events/events/item/307-research-symposium-on-emerging-trends-in-artificial-intelligence-on-25-and-26th-february-2022
# https://www.dkte.ac.in/news-and-events/events
# /news-and-events/events/item/302-virtual-international-conference-on-innovations-in-textiles-products-and-processes-itpp-21-on-2nd-and-3rd-september-2021
# https://www.dkte.ac.in/news-and-events/events
# /news-and-events/events/item/299-tech-symposium-2k21
# https://www.dkte.ac.in/news-and-events/events
# /news-and-events/events/item/295-www-taimu-dkte-tech
# https://www.dkte.ac.in/news-and-events/events
# /news-and-events/events/item/291-one-week-online-short-term-program-on-artificial-intelligence-and-machine-learning
# https://www.dkte.ac.in/news-and-events/events
# #carouselEventsection
# #carouselEventsection
# https://casinoscad.com/blackjack/
# /./about-us/vision-mission
# https://casinosworld.ca/casinos/spin-casino/
# /about-us/about-dkte-society
# #student
# #project-awards
# #student-support
# #gallery
# https://www.dkte.ac.in/life-dkte/facilities
# https://www.dkte.ac.in/life-dkte/campus
# https://www.dkte.ac.in/life-dkte/library
# https://www.dkte.ac.in/life-dkte/student-co-curricular-activities
# #
# https://www.dkte.ac.in/life-dkte/student-awards
# https://www.dkte.ac.in/life-dkte/student-support
# https://www.dkte.ac.in/life-dkte/gallery
# #
# /about-us/director-s-message
# https://www.facebook.com/dktestei/
# https://www.dkte.ac.in/placement/our-placements
# #
# /images/pdf/Degree_Prospectus.pdf
# https://www.facebook.com/dktestei/
# https://twitter.com/dktestei/
# https://www.instagram.com/dktestei/
# https://www.linkedin.com/school/dkte/
# https://www.youtube.com/c/dktestei
# None
# None
# None
# None
# /index.php
# https://www.facebook.com/dktestei/
# https://twitter.com/dktestei
# https://www.instagram.com/dkte_tei/
# https://www.linkedin.com/school/dkte/
# tel:02302421300
# #
# #
# mailto:dktestextile@gmail.com
# tel:18008431300
# /about-us/about-dkte-society
# /about-us/chairman-s-message
# /about-us/director-s-message
# /about-us/vision-mission
# /about-us/quality-policy
# /about-us/board-of-examination
# /2-uncategorised/114-parents
# /about-us/key-facutly
# /contact-us
# /admissions/ug-admission/admission-process
# https://www.dkte.ac.in/index.php/admissions/ug-admission/eligibility
# https://www.dkte.ac.in/index.php/admissions/international-students/contact-admissions-office
# /life-dkte/facilities
# /2-uncategorised/133-campus
# /life-dkte/library
# /life-dkte/student-curricular-activities
# /placement/testimonials
# /life-dkte/student-awards
# /life-dkte/student-support
# /news-and-events/anouncement
# /news-and-events/news
# /news-and-events/events
# /recruitments
# /ambar
# /images/pdf/Degree_Prospectus.pdf
# /academic-calendar
# /mandatory-disclosures
# #
# #
# https://drive.google.com/file/d/1tiKY9ptGZPQQXjmUNQ2oAmhEDcU4ZLiR/view?usp=sharing
# https://drive.google.com/file/d/1GAgobUfXB2Ho3CS3YiVUDHdUv3SXmK-D/view?usp=sharing
# /aqar
# /documents
# https://drive.google.com/file/d/103nLGB5rdlb6rS2i6GtzRN27aZo5y7ja/view?usp=sharing
# /dkte-ip-cell
# https://www.dimakhconsultants.com/
# #
# https://forms.gle/D1MN4GZ1hGNdKMcR9

# %%
url2="https://aicte-india.org/"
reqs2=requests.get(url2)
soup2=BeautifulSoup(reqs2.text)

# %%
urls2=[]
for link in soup2.find_all('a'):
    print(link.get('href'))
# Out:
# #main-content
# https://aicte-india.org/screen-reader
# #
# #
# #
# https://hindi.aicte-india.org
# https://hindi.aicte-india.org
# https://portal.aicte-india.org/partnerportal_enu
# https://www.facebook.com/officialaicte
# https://twitter.com/AICTE_INDIA
# https://drive.google.com/file/d/1CYQSHsjoIRJ4rfw-VX0-VgG_TPqRd3nZ/view?usp=sharing
# /
# /
# /about-us/history
# /about-us/overview
# /about-us/history
# /about-us/leadership-team
# /about-us/organisation-structure
# /about-us/messages
# /office
# /news/news-overview
# /news/news-overview
# /news
# /press-releases
# /picture-gallery
# /news-video
# /about-us/events
# /bureaus
# /bureaus
# /bureaus/approval
# /bureaus/policy-academic-planning
# /bureaus/administration
# /bureaus/finance
# https://www.aicte-india.org/bureaus
# /Initiatives
# https://aicte-india.org/Initiatives
# /Initiatives/smart-india-hackathon
# https://swayam.gov.in/
# /education/collaborations/moucii
# /Initiatives/clean-green-campus
# /Initiatives/startup-contest-2017
# /AICTE%20Vishwakarma%20Award%202020
# https://aicte-india.org/sites/default/files/Jal%20Shakti.pdf
# https://aicte-india.org/sites/default/files/Ons%20student%20On%20tree.pdf
# https://internship.aicte-india.org/
# https://neat.aicte-india.org/
# https://aslap.aicte-india.org/
# /schemes
# /schemes
# /schemes/students-development-schemes
# /schemes/staff-development-schemes
# /schemes/institutional-development-schemes
# /schemes/research-innovations-development-schemes
# /schemes/other-schemes
# /education/overview
# /education/overview
# /education/collaborations
# /education/finishing-education
# /education/vocational-education
# /education/community-colleges
# /education/distance-education
# /education/institutions
# https://www.aicte-india.org/flipbook/Best_Practices/
# /education/IT-and-ICT
# /education/model-syllabus
# /education/library-services
# /policies-reforms
# /opportunities/students/overview
# /opportunities/faculty/overview
# /opportunities/students/overview
# /schemes/institutional-development-schemes
# https://facilities.aicte-india.org/dashboard/pages/dashboardaicte.php
# https://facilities.aicte-india.org/dashboard/pages/dashboardaicte.php
# https://facilities.aicte-india.org/dashboard/pages/angulardashboard.php#!/approved
# https://facilities.aicte-india.org/dashboard/pages/angulardashboard.php#!/nripiofcinstitutes
# https://facilities.aicte-india.org/dashboard/pages/faculties.php
# https://facilities.aicte-india.org/dashboard/pages/angulardashboard.php#!/graphs
# https://facilities.aicte-india.org/dashboard_pmkvy/pages/dashboardaicte.php
# https://facilities.aicte-india.org/dashboard_pmkvy/pages/approvedinstitutes.php
# https://facilities.aicte-india.org/dashboard/pages/aicte_nba.php
# https://facilities.aicte-india.org/dashboard/pages/angulardashboard.php#!/unapproved
# https://facilities.aicte-india.org/dashboard/pages/angulardashboard.php#!/closedcourse
# https://facilities.aicte-india.org/dashboard/pages/angulardashboard.php#!/closedinstitute
# https://facilities.aicte-india.org/dashboard/pages/aicte_autonomus.php
# /bulletins
# /bulletins
# /bulletins/advertisements/
# /bulletins/circulars
# /bulletins/tenders
# https://www.aicte-india.org/bulletins/newsletter?lang=All&lang=All
# /bulletins/annoucement
# javascript:;
# https://parakh.aicte-india.org/
# https://parakh.aicte-india.org/
# https://aicte-india.org/ap2022/
# https://aicte-india.org/ap2022/
# https://aicte-india.org/about-us/overview
# https://aicte-india.org/about-us/overview
# https://aicte-india.org/schemes
# https://aicte-india.org/schemes
# /
# /about-us/history
# /about-us/overview
# /about-us/history
# /about-us/leadership-team
# /about-us/organisation-structure
# /about-us/messages
# /office
# /news/news-overview
# /news/news-overview
# /news
# /press-releases
# /picture-gallery
# /news-video
# /about-us/events
# /bureaus
# /bureaus
# /bureaus/approval
# /bureaus/policy-academic-planning
# /bureaus/administration
# /bureaus/finance
# https://www.aicte-india.org/bureaus
# /Initiatives
# https://aicte-india.org/Initiatives
# /Initiatives/smart-india-hackathon
# https://swayam.gov.in/
# /education/collaborations/moucii
# /Initiatives/clean-green-campus
# /Initiatives/startup-contest-2017
# /AICTE%20Vishwakarma%20Award%202020
# https://aicte-india.org/sites/default/files/Jal%20Shakti.pdf
# https://aicte-india.org/sites/default/files/Ons%20student%20On%20tree.pdf
# https://aslap.aicte-india.org/
# https://neat.aicte-india.org/
# https://internship.aicte-india.org/
# /schemes
# /schemes
# /schemes/students-development-schemes
# /schemes/staff-development-schemes
# /schemes/institutional-development-schemes
# /schemes/research-innovations-development-schemes
# /schemes/other-schemes
# /education/overview
# /education/overview
# /education/collaborations
# /education/finishing-education
# /education/vocational-education
# /education/community-colleges
# /education/distance-education
# /education/institutions
# https://www.aicte-india.org/flipbook/Best_Practices/
# /education/IT-and-ICT
# /education/model-syllabus
# /education/library-services
# /policies-reforms
# /opportunities/students/overview
# /opportunities/faculty/overview
# /opportunities/students/overview
# /schemes/institutional-development-schemes
# https://facilities.aicte-india.org/dashboard/pages/dashboardaicte.php
# https://facilities.aicte-india.org/dashboard/pages/dashboardaicte.php
# https://facilities.aicte-india.org/dashboard/pages/angulardashboard.php#!/approved
# https://facilities.aicte-india.org/dashboard/pages/angulardashboard.php#!/nripiofcinstitutes
# https://facilities.aicte-india.org/dashboard/pages/faculties.php
# https://facilities.aicte-india.org/dashboard/pages/angulardashboard.php#!/graphs
# https://facilities.aicte-india.org/dashboard_pmkvy/pages/dashboardaicte.php
# https://facilities.aicte-india.org/dashboard_pmkvy/pages/approvedinstitutes.php
# https://facilities.aicte-india.org/dashboard/pages/aicte_nba.php
# https://facilities.aicte-india.org/dashboard/pages/angulardashboard.php#!/unapproved
# https://facilities.aicte-india.org/dashboard/pages/angulardashboard.php#!/closedcourse
# https://facilities.aicte-india.org/dashboard/pages/angulardashboard.php#!/closedinstitute
# https://facilities.aicte-india.org/dashboard/pages/aicte_autonomus.php
# /bulletins
# /bulletins
# /bulletins/advertisements/
# /bulletins/circulars
# /bulletins/tenders
# https://www.aicte-india.org/bulletins/newsletter?lang=All
# /bulletins/annoucement
# https://parakh.aicte-india.org/
# https://free.aicte-india.org/
# https://internship.aicte-india.org/
# /atal
# https://aicte-india.org/odl/
# /bureaus/jk
# /policy-reforms
# https://www.aicte-india.org/bureaus/margdarshak
# https://drive.aicte-india.org/yoga/
# https://drive.aicte-india.org/jk/
# https://www.aicte-india.org/sites/default/files/UPDATED%20DEFENCE%20TECHNOLOGY%20Institutes.pdf
# https://www.aicte-india.org/schemes/KARMA
# bureaus/quick-link
# https://aicte-india.org/about-us/overview
# /content/aicte-calendar-2022
# https://www.aicte-india.org/sites/default/files/AICTE_Cal_2022_Final_31.12.2021_compressed.pdf
# /content/revised-academic-calendar-ay-2021-22-0
# https://www.aicte-india.org/sites/default/files/revised_academic_calendar_approval_2021-22.pdf
# /content/notice-announcement-ro-academic-calendar-ay-2021-22
# https://aicte-india.org/sites/default/files/announcement_ay2021-22_compressed.pdf
# /content/scheme-foster-cross-border-partnerships-focussed-creating-platform-opens-path-collaborative
# https://www.aicte-india.org/sites/default/files/Mitacs%20Scheme%20Guidelines.pdf
# /content/request-proposal-selection-vendor-providing-service-through-it-professional-manpower-system
# https://www.aicte-india.org/sites/default/files/ONOD-Manpower%20RFP.pdf
# /content/request-proposal-hiring-taxies-daily-basis-swro-bengaluru-aicte
# https://aicte-india.org/sites/default/files/Tender%20for%20car%20rental.pdf
# /content/notice-inviting-e-tender-moe-innovation-cell
# https://www.aicte-india.org/sites/default/files/MIC%20Advt.%2018.01.2022.pdf
# /content/request-proposal-outsourcing-technically-skilled-professionals-operate-edit-record-maintain
# https://aicte-india.org/sites/default/files/UPLOADED%20MANPOWER%20RFP%20%28FINAL%20LEGAL%20VER%29%20STUDIO.pdf
# https://aicte-india.org/bulletins
# https://aicte-india.org/bureaus
# https://aicte-india.org/bureaus/approval
# bureaus/policy-academic-planning
# https://aicte-india.org/bureaus/administration
# https://aicte-india.org/bureaus/finance
# https://aslap.aicte-india.org
# https://aicte-india.org/bureaus/jk
# https://aicte-india.org/bureaus/jk
# https://aicte-india.org/bureaus/jk
# http://unnatbharatabhiyan.gov.in/
# http://unnatbharatabhiyan.gov.in/
# http://unnatbharatabhiyan.gov.in/
# http://scholarships.gov.in/
# https://www.vidyalakshmi.co.in/Students/indexPopup
# https://www.aicte-india.org/schemes/students-development-schemes
# http://www.ciiinnovation.in/
# https://aicte-india.org/opportunities/students/facilites
# https://aicte-india.org/opportunities/students/facilites
# https://aicte-india.org/opportunities/students/facilities-differently-abled
# https://aicte-india.org/opportunities/students/facilities-differently-abled
# https://aicte-india.org/opportunities/students/research-funds
# https://aicte-india.org/opportunities/students/research-funds
# https://www.facebook.com/officialaicte
# https://twitter.com/AICTE_INDIA
# https://drive.google.com/file/d/1CYQSHsjoIRJ4rfw-VX0-VgG_TPqRd3nZ/view?usp=sharing
# /terms-conditions
# /privacy-policy
# https://www.aicte-india.org/grievance/rti
# /reports/overview
# https://www.aicte-india.org/directory
# /centralized-support-system
# /survey-form
# https://facilities.aicte-india.org/dashboard/pages/angulardashboard.php#!/approved
# /contact
# https://dashboards.aicte-india.org/
# https://facilities.aicte-india.org/pgdm/
# #Top
